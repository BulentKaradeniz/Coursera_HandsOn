# %% [markdown]
# ![image.png](attachment:9520e69d-63f8-4e8a-bd04-cca17361edef.png)

# %% [markdown]
# ![image.png](attachment:dabac7ce-00ba-4c05-82c1-b29abe69d5dd.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](attachment:2-title.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![image.png](attachment:d42ce57a-034d-47f7-9528-5604e708113f.png)

# %% [markdown]
# ![image.png](attachment:3-intro.png)

# %% [markdown]
# ![image.png](attachment:b202f301-bb12-4133-855c-8938ee6f49f2.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %%
ordered_list = ["Python", "R", "SQL"]
for index, language in enumerate(ordered_list, start=1):
    print(f"{index}. {language}")
# Out:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ![image.png](attachment:bf790f21-0d30-4ae1-a958-af0553ebd098.png)

# %% [markdown]
# ![image.png](attachment:d14d2ff1-2e37-45b1-805f-3e0cd56c2c93.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1-NumPy
# 2-Pandas
# 3-Matplotlib

# %% [markdown]
# ![image.png](attachment:3894551e-b318-4961-aaa4-298dc2092722.png)

# %% [markdown]
# ![image.png](attachment:26eed2c9-372d-41dc-a390-53bdd145347a.png)

# %% [markdown]
# # Data Science Tools
#
# | Tools                |
# |----------------------|
# | Jupyter Notebook     |
# | RStudio              |
# | VS Code with Python  |

# %% [markdown]
# # Data Science Tools
#
# | Tools                |
# |----------------------|
# | Jupyter Notebook     |
# | RStudio              |
# | VS Code with Python  |

# %% [markdown]
# ![image.png](attachment:c8d96bc2-1720-4554-84d9-732e6274440d.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# Addition
result_addition = 5 + 3
print("Addition:", result_addition)

# Subtraction
result_subtraction = 10 - 4
print("Subtraction:", result_subtraction)

# Multiplication
result_multiplication = 6 * 7
print("Multiplication:", result_multiplication)

# Division
result_division = 15 / 3
print("Division:", result_division)

# Exponentiation
result_exponentiation = 2 ** 4
print("Exponentiation:", result_exponentiation)

# Modulus (Remainder)
result_modulus = 20 % 3
print("Modulus:", result_modulus)
# Out:
# Addition: 8
# Subtraction: 6
# Multiplication: 42
# Division: 5.0
# Exponentiation: 16
# Modulus: 2

# %% [markdown]
# ![image.png](attachment:c3b99551-504d-49fb-bf18-61dc31b63769.png)

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
#  This  a simple arithmetic expression to multiply then add integers

# %% [markdown]
# ![image.png](attachment:9041c7ae-58a8-41a6-9256-1b819c7ad743.png)

# %% [markdown]
#  This will convert 200 minutes to  hours by dividing by 60.

# %%
hours = 200 / 60
print(" 200 minutes = ", hours)
# Out:
#  200 minutes =  3.3333333333333335

# %% [markdown]
# ![image.png](attachment:d8199a75-0cb1-4917-a904-0e7fd70e5841.png)

# %% [raw]
# **Objectives:**
#
# - List popular languages for Data Science.
# - Introduce commonly used libraries in Data Science.
# - Create a Markdown table in Jupyter Notebook.
# - Provide examples of evaluating arithmetic expressions in Python.
# - Demonstrate how to structure content in a Jupyter Notebook.

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science.
# - Introduce commonly used libraries in Data Science.
# - Create a Markdown table in Jupyter Notebook.
# - Provide examples of evaluating arithmetic expressions in Python.
# - Demonstrate how to structure content in a Jupyter Notebook.

# %% [markdown]
# ![image.png](attachment:4364ce90-bdaa-4b2c-8806-e0d1de60deec.png)
